# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index('PassengerId').head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
titanic.Sex.value_counts().plot(kind='pie', explode=(0.05,0.05), fontsize=14, autopct='%3.1f%%',
                                       shadow=True, figsize=(10,10), colors=['blue', 'red'], legend=True)

plt.ylabel('Sex Proporation')
plt.title('Pie Chart showing the proportion of Sex')
# Out:
# Text(0.5,1,'Pie Chart showing the proportion of Sex')

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
sns.scatterplot(x='Age', y='Fare', hue='Sex', data=titanic)

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic.Survived.sum()
# Out:
# 342

# %%
sns.scatterplot(x='Age', y='Pclass', hue='Survived', data=titanic)

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
titanic.Fare.sort_values(ascending=True).plot.hist(bins = np.arange(0,600,10))

plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Fare Paid Histrogram')
# Out:
# Text(0.5,1,'Fare Paid Histrogram')
