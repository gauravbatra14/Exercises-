# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
inv_ff_US = pd.read_csv("https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv")
inv_ff_US.head()
# Out:
#          Date  Total Equity  ...  Municipal Bond  Total
# 0  2012-12-05         -7426  ...            1107  -2183
# 1  2012-12-12         -8783  ...             219  -6842
# 2  2012-12-19         -5496  ...           -3369  -5466
# 3  2012-12-26         -4451  ...            -722  -1291
# 4  2013-01-02        -11156  ...             280  -8931
#
# [5 rows x 9 columns]

# %%
inv_ff_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
# Date               44 non-null object
# Total Equity       44 non-null int64
# Domestic Equity    44 non-null int64
# World Equity       44 non-null int64
# Hybrid             44 non-null int64
# Total Bond         44 non-null int64
# Taxable Bond       44 non-null int64
# Municipal Bond     44 non-null int64
# Total              44 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
# Weekly Data

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
inv_ff_US.set_index('Date', inplace=True)

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
type(inv_ff_US.index)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
inv_ff_US.index = pd.to_datetime(inv_ff_US.index)
type(inv_ff_US.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
monthly = inv_ff_US.resample('M').sum()
monthly
# Out:
#             Total Equity  Domestic Equity  ...  Municipal Bond  Total
# Date                                       ...
# 2012-12-31        -26156           -23126  ...           -2765 -15782
# 2013-01-31          3661            -1627  ...            2735  18540
# 2013-02-28             0                0  ...               0      0
# 2013-03-31             0                0  ...               0      0
# 2013-04-30             0                0  ...               0      0
# 2013-05-31             0                0  ...               0      0
# 2013-06-30             0                0  ...               0      0
# 2013-07-31             0                0  ...               0      0
# 2013-08-31             0                0  ...               0      0
# 2013-09-30             0                0  ...               0      0
# 2013-10-31             0                0  ...               0      0
# 2013-11-30             0                0  ...               0      0
# ...

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
monthly = monthly.dropna(axis=1, how = 'all')

# %%
monthly
# Out:
#             Total Equity  Domestic Equity  ...  Municipal Bond  Total
# Date                                       ...
# 2012-12-31        -26156           -23126  ...           -2765 -15782
# 2013-01-31          3661            -1627  ...            2735  18540
# 2013-02-28             0                0  ...               0      0
# 2013-03-31             0                0  ...               0      0
# 2013-04-30             0                0  ...               0      0
# 2013-05-31             0                0  ...               0      0
# 2013-06-30             0                0  ...               0      0
# 2013-07-31             0                0  ...               0      0
# 2013-08-31             0                0  ...               0      0
# 2013-09-30             0                0  ...               0      0
# 2013-10-31             0                0  ...               0      0
# 2013-11-30             0                0  ...               0      0
# ...

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
year = monthly.resample('AS-JAN').sum()
year
# Out:
#             Total Equity  Domestic Equity  ...  Municipal Bond  Total
# Date                                       ...
# 2012-01-01        -26156           -23126  ...           -2765 -15782
# 2013-01-01          3661            -1627  ...            2735  18540
# 2014-01-01           330           -44689  ...           14896  79787
# 2015-01-01         15049           -10459  ...            8041  48357
#
# [4 rows x 8 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.
